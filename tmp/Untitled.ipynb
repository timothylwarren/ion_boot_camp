# %%
import numpy
from PIL import Image, ImageDraw
import filehandling as fh

# %%
ls
# Out:
# Untitled.ipynb         boot_camp_intro.ipynb  mndata.pck
# __pycache__/           filehandling.py        tst
# alldt_animal1.pck      meta_dt_anim1.pck      untitled folder 2/

# %%
dt=fh.open_pickle('alldt_animal1.pck')
# Out:
# pickle_name is alldt_animal1.pck

# %%
dt.keys()
# Out:
# dict_keys(['list_of_tifstacks', 'meta_dt'])

# %%
stack=dt['list_of_tifstacks'][0]

# %%
stack.keys()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-f51f713e56af> in <module>
# ----> 1 stack.keys()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'keys'

# %%
stack
# Out:
# array([[[ 187,  203,  187, ...,  196,  183,  195],
#         [ 188,  185,  191, ...,  195,  196,  193],
#         [ 184,  195,  196, ...,  181,  192,  189],
#         ...,
#         [ 193,  198,  200, ...,  183,  193,  198],
#         [ 196,  155,  193, ...,  184,  207,  196],
#         [ 154,  189,  194, ...,  195,  188,  197]],
#
#        [[ 192,  177,  195, ...,  187,  191,  176],
#         [ 185,  206,  197, ...,  185,  203,  192],
#         [ 200,  165,  196, ...,  178,  194,  189],
#         ...,
#         [ 187,  194,  208, ...,  181,  216,  195],
#         [ 182,  177,  199, ...,  192,  199,  189],
#         [ 197,  194,  190, ...,  183,  187,  153]],
#
#        [[ 195,  192,  195, ..., 1124,  201,  191],
#         [ 195, 1057,  189, ...,  187,  196,  197],
#         [1831,  152,  189, ...,  175,  191,  159],
#         ...,
#         [ 190,  182,  201, ...,  194,  204,  199],
#         [ 183,  185,  178, ...,  188,  191,  182],
# ...

# %%
numpy.shape(stack)
# Out:
# (125, 100, 150)

# %%
mn_stack=numpy.mean(stack,axis=0)

# %%
plt.imshow(mn_stack)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-9fed6122544b> in <module>
# ----> 1 plt.imshow(mn_stack)
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(mn_stack)

# %%
img = Image.new('L', (30, 30), 0)

# %%
polygon = [(60,80),(100,60),(60,40),(100,40)]

# %%
plt.imshow(mn_stack)
ImageDraw.Draw.polygon(polygon, outline=1, fill=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-e590ce8c6e1a> in <module>
#       1 plt.imshow(mn_stack)
# ----> 2 ImageDraw.Draw.polygon(polygon, outline=1, fill=1)
#
# AttributeError: 'function' object has no attribute 'polygon'

# %%
img
# Out:
# <PIL.Image.Image image mode=L size=30x30 at 0x1154F3B00>

# %%
from skimage.draw import polygon
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-24-0c1e08d6f908> in <module>
# ----> 1 from skimage.draw import polygon
#
# ~/anaconda3/lib/python3.7/site-packages/skimage/__init__.py in <module>
#     165         _raise_build_error(e)
#     166     # All skimage root imports go here
# --> 167     from .util.dtype import (img_as_float32,
#     168                              img_as_float64,
#     169                              img_as_float,
#
# ~/anaconda3/lib/python3.7/site-packages/skimage/util/__init__.py in <module>
#       6 from .apply_parallel import apply_parallel
#       7
# ----> 8 from .arraycrop import crop
#       9 from ._regular_grid import regular_grid, regular_seeds
#      10 from .unique import unique_rows
#
# ~/anaconda3/lib/python3.7/site-packages/skimage/util/arraycrop.py in <module>
#       6
#       7 import numpy as np
# ...

# %%
matplotlib notebook
